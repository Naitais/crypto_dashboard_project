# %%
import pandas as pd
from sqlalchemy import create_engine
df_cryptos = pd.read_json(r'dataset\response_1692132599095.json', dtype='unicode')

# %%
db_user= 'root'
db_password= 'naitais'
db_host= '172.19.0.2'
db_port = '3306'

db_name = 'crypto_currencies'

db_url = f"mysql+mysqlconnector://{db_user}:{db_password}@{db_host}:{db_port}/{db_name}"
engine = create_engine(db_url)

# %%
table_name = "top_100_cryptos"
df_cryptos.to_sql(name=table_name, con=engine, if_exists='replace', index=False)
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File c:\Users\Administrator\AppData\Local\Programs\Python\Python311\Lib\site-packages\mysql\connector\connection_cext.py:302, in CMySQLConnection._open_connection(self)
#     301 try:
# --> 302     self._cmysql.connect(**cnx_kwargs)
#     303     self._cmysql.converter_str_fallback = self._converter_str_fallback
#
# MySQLInterfaceError: Can't connect to MySQL server on '172.19.0.2:3306' (10060)
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# File c:\Users\Administrator\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\engine\base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144 try:
# ...
